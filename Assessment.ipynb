# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv'

# %%
datak=pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
datak
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
datak.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
datak=datak.fillna('mcf')

# %%
datak.isnull().sum()
# Out:
# record_id                       0
# utility_id_ferc1                0
# report_year                     0
# plant_name_ferc1                0
# fuel_type_code_pudl             0
# fuel_unit                       0
# fuel_qty_burned                 0
# fuel_mmbtu_per_unit             0
# fuel_cost_per_unit_burned       0
# fuel_cost_per_unit_delivered    0
# fuel_cost_per_mmbtu             0
# dtype: int64

# %%
datak.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29518    False
# 29519    False
# 29520    False
# 29521    False
# 29522    False
# Length: 29523, dtype: bool

# %%
datak.duplicated().sum()
# Out:
# 0

# %%
datak.groupby('report_year')['fuel_cost_per_unit_delivered'].mean()
# Out:
# report_year
# 1994       63.636060
# 1995       32.735269
# 1996     9196.705948
# 1997    11140.197239
# 1998      287.154420
# 1999       25.551627
# 2000      985.362877
# 2001       60.050396
# 2002       47.594361
# 2003       55.663493
# 2004      139.524275
# 2005       41.438184
# 2006       38.657484
# 2007       43.325023
# 2008       58.588197
# 2009      652.694163
# 2010       91.862105
# 2011       59.774667
# 2012       60.994502
# 2013      172.307591
# 2014      192.737183
# 2015      326.535511
# 2016      103.901761
# 2017       46.196861
# 2018      499.269966
# Name: fuel_cost_per_unit_delivered, dtype: float64

# %%
datak.groupby('report_year').first()
# Out:
#                            record_id  utility_id_ferc1    plant_name_ferc1  \
# report_year
# 1994           f1_fuel_1994_12_1_0_7                 1            rockport
# 1995         f1_fuel_1995_12_200_0_1               200    aroostook valley
# 1996         f1_fuel_1996_12_204_0_1               204            seabrook
# 1997           f1_fuel_1997_12_1_0_7                 1  rockport total aeg
# 1998           f1_fuel_1998_12_1_0_7                 1  rockport total aeg
# 1999         f1_fuel_1999_12_141_0_1               141            boardman
# 2000         f1_fuel_2000_12_141_0_1               141            boardman
# 2001         f1_fuel_2001_12_195_0_1               195           pulliam 3
# 2002         f1_fuel_2002_12_195_0_1               195           pulliam 3
# 2003         f1_fuel_2003_12_283_0_1               283       talbot energy
# 2004           f1_fuel_2004_12_1_0_7                 1  rockport total aeg
# ...

# %%
datak.groupby('fuel_type_code_pudl').mean()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                       115.637534  2004.623143     1.903473e+06
# gas                        124.122062  2005.978060     4.843183e+06
# nuclear                    107.397311  2002.970660     5.454838e+06
# oil                        113.236235  2007.195933     6.311677e+04
# other                      110.467066  2001.700599     2.948137e+06
# waste                      154.253968  2005.650794     1.171914e+05
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                           20.762780                  67.421830
# gas                             1.021913                  13.659397
# nuclear                        17.582120                4955.157002
# oil                             5.814377                 168.877086
# other                           0.572752                  18.253856
# ...

# %%
datak.groupby('fuel_type_code_pudl').sum()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                           988354     17133514     1.626898e+10
# gas                           1425666     23040664     5.562880e+10
# nuclear                         87851      1638430     4.462058e+09
# oil                            913137     16186028     5.089737e+08
# other                           18448       334284     4.923388e+08
# waste                           68026       884492     5.168139e+07
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_type_code_pudl
# coal                       177459.483188                 576254.381
# gas                         11737.687844                 156891.829
# nuclear                     14382.174064                4053318.428
# oil                         46887.135739                1361824.819
# other                          95.649646                   3048.394
# ...

# %%
datak.groupby('fuel_type_code_pudl').max()
# Out:
#                                    record_id  utility_id_ferc1  report_year  \
# fuel_type_code_pudl
# coal                  f1_fuel_2018_12_99_0_2               514         2018
# gas                   f1_fuel_2018_12_99_1_4               513         2018
# nuclear               f1_fuel_2018_12_8_0_14               454         2018
# oil                   f1_fuel_2018_12_95_1_5               514         2018
# other                f1_fuel_2016_12_98_0_13               281         2016
# waste                 f1_fuel_2018_12_98_0_7               432         2018
#
#                         plant_name_ferc1 fuel_unit  fuel_qty_burned  \
# fuel_type_code_pudl
# coal                 zimmer- aepgr share       ton      555894250.0
# gas                                 zuni       ton      166385450.0
# nuclear                             zion     mwhth       50038564.0
# oil                                 zuni       ton       46460148.0
# ...

# %%
datak.groupby('plant_name_ferc1').sum()
# Out:
#                      utility_id_ferc1  report_year  fuel_qty_burned  \
# plant_name_ferc1
# (1)sta98                          151         1994          33044.0
# (2) scriba sta. 99                151         1994         107129.0
# (n) contra costa                  133         1995       11338219.0
# (n) pittsburg                     133         1995       34851184.0
# (n)(t)moss landing                133         1994       87863451.0
# ...                               ...          ...              ...
# zimmer- aepgr share               904         4028         727007.0
# zion                               96         5985        3242901.0
# zorn                             1056        24008         232678.0
# zorn ct                           880        20134          53674.0
# zuni                             2465        34068        5101375.0
#
#                      fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# plant_name_ferc1
# ...

# %%
datak.groupby('fuel_unit').sum()
# Out:
#            utility_id_ferc1  report_year  fuel_qty_burned  \
# fuel_unit
# bbl                  904112     16052981     4.905918e+08
# gal                    9624       168643     2.897555e+07
# gramsU                58092       928929     3.695163e+08
# kgU                    5850       220649     2.482233e+07
# mcf                 1430371     23136357     5.614868e+10
# mmbtu                 17378       361069     2.456512e+09
# mwdth                  8377       190113     6.436056e+07
# mwhth                 11180       200640     2.892479e+09
# ton                 1056498     17958031     1.493689e+10
#
#            fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# fuel_unit
# bbl               46263.918771                1359538.172
# gal                 463.998760                    857.063
# gramsU            11568.374241                 138984.280
# kgU                 352.157634                3909732.918
# mcf               13700.562142                 151327.684
# ...

# %%
#fuel type and average cost per unit
datak.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].mean()
# Out:
# fuel_type_code_pudl
# coal         67.421830
# gas          13.659397
# nuclear    4955.157002
# oil         168.877086
# other        18.253856
# waste        19.518122
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
datak.groupby('fuel_unit')['fuel_qty_burned'].sum()
# Out:
# fuel_unit
# bbl       4.905918e+08
# gal       2.897555e+07
# gramsU    3.695163e+08
# kgU       2.482233e+07
# mcf       5.614868e+10
# mmbtu     2.456512e+09
# mwdth     6.436056e+07
# mwhth     2.892479e+09
# ton       1.493689e+10
# Name: fuel_qty_burned, dtype: float64

# %%
datak.groupby('fuel_unit')['fuel_qty_burned'].mean()
# Out:
# fuel_unit
# bbl       6.133931e+04
# gal       3.449470e+05
# gramsU    7.963714e+05
# kgU       2.256575e+05
# mcf       4.868101e+06
# mmbtu     1.364729e+07
# mwdth     6.774796e+05
# mwhth     2.892479e+07
# ton       1.667436e+06
# Name: fuel_qty_burned, dtype: float64

# %%
datak.groupby('fuel_type_code_pudl')['fuel_qty_burned'].sum()
# Out:
# fuel_type_code_pudl
# coal       1.626898e+10
# gas        5.562880e+10
# nuclear    4.462058e+09
# oil        5.089737e+08
# other      4.923388e+08
# waste      5.168139e+07
# Name: fuel_qty_burned, dtype: float64

# %%
datak.groupby('report_year')['fuel_qty_burned'].sum()
# Out:
# report_year
# 1994    3.364163e+09
# 1995    4.458192e+09
# 1996    2.768693e+09
# 1997    3.077973e+09
# 1998    3.617070e+09
# 1999    3.445345e+09
# 2000    3.394100e+09
# 2001    3.147821e+09
# 2002    2.585502e+09
# 2003    2.287121e+09
# 2004    2.124797e+09
# 2005    2.244703e+09
# 2006    2.432879e+09
# 2007    2.573119e+09
# 2008    2.513047e+09
# 2009    2.633401e+09
# 2010    3.056312e+09
# 2011    3.052052e+09
# 2012    3.414637e+09
# 2013    3.287065e+09
# 2014    3.161710e+09
# 2015    3.650763e+09
# 2016    3.818861e+09
# 2017    3.329380e+09
# 2018    3.974124e+09
# Name: fuel_qty_burned, dtype: float64

# %%
#Fuel cost of individual power plant
datak.groupby('plant_name_ferc1')['fuel_cost_per_unit_delivered'].sum()
# Out:
# plant_name_ferc1
# (1)sta98                 3.500
# (2) scriba sta. 99       1.274
# (n) contra costa         0.000
# (n) pittsburg            0.000
# (n)(t)moss landing       0.000
#                         ...
# zimmer- aepgr share    254.238
# zion                     0.000
# zorn                    52.981
# zorn ct                 56.655
# zuni                   526.138
# Name: fuel_cost_per_unit_delivered, Length: 2315, dtype: float64

# %%
#How fuel cost impact viability of different generation sources
datak.groupby('fuel_type_code_pudl')['fuel_cost_per_unit_burned'].sum()
# Out:
# fuel_type_code_pudl
# coal        576254.381
# gas         156891.829
# nuclear    4053318.428
# oil        1361824.819
# other         3048.394
# waste         8607.492
# Name: fuel_cost_per_unit_burned, dtype: float64

# %%
#Competitiveness of renewable energy
datak.groupby('fuel_type_code_pudl')['fuel_qty_burned'].sum()
# Out:
# fuel_type_code_pudl
# coal       1.626898e+10
# gas        5.562880e+10
# nuclear    4.462058e+09
# oil        5.089737e+08
# other      4.923388e+08
# waste      5.168139e+07
# Name: fuel_qty_burned, dtype: float64

# %%
#How generation mix of diff utilities evolved over time
datak.groupby('report_year')['utility_id_ferc1'].sum()
# Out:
# report_year
# 1994    131059
# 1995    132277
# 1996    118281
# 1997    118553
# 1998    121599
# 1999    113634
# 2000    152518
# 2001    153935
# 2002    145027
# 2003    149317
# 2004    144379
# 2005    153585
# 2006    145653
# 2007    146675
# 2008    148324
# 2009    144366
# 2010    148789
# 2011    150126
# 2012    150117
# 2013    146377
# 2014    151368
# 2015    140551
# 2016    137643
# 2017    130209
# 2018    127120
# Name: utility_id_ferc1, dtype: int64

# %%
#Summary Statistics
datak.describe(include='all')
# Out:
#                      record_id  utility_id_ferc1   report_year  \
# count                    29523      29523.000000  29523.000000
# unique                   29523               NaN           NaN
# top     f1_fuel_2005_12_89_0_9               NaN           NaN
# freq                         1               NaN           NaN
# mean                       NaN        118.601836   2005.806050
# std                        NaN         74.178353      7.025483
# min                        NaN          1.000000   1994.000000
# 25%                        NaN         55.000000   2000.000000
# 50%                        NaN        122.000000   2006.000000
# 75%                        NaN        176.000000   2012.000000
# max                        NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29523     2.952300e+04
# ...

# %%
#visualization

# %%
plt.figure(figsize=(14,10))

sns.set(style='darkgrid')

# %%
sns.barplot(x=datak.fuel_type_code_pudl,y=datak.fuel_qty_burned,color='#69b3a2')
plt.xticks(rotation=90)
plt.xlabel('quantity of fuel type burned')
# Out:
# Text(0.5, 0, 'quantity of fuel type burned')

# %%
sns.boxplot(x=datak.fuel_type_code_pudl,y=datak.fuel_qty_burned,color='#69b3a2')
plt.xticks(rotation=90)
plt.xlabel('fuel quantity burned per year')
# Out:
# Text(0.5, 0, 'fuel quantity burned per year')

# %%
sns.violinplot(x=datak.report_year, y=datak.fuel_qty_burned)
plt.xticks(rotation=90)
plt.xlabel('fuel quantity burned per year')
# Out:
# Text(0.5, 0, 'fuel quantity burned per year')

# %%
sns.barplot(x=datak.report_year, y=datak.fuel_qty_burned)
plt.xticks(rotation=90)
plt.xlabel('fuel quantity burned per year')
# Out:
# Text(0.5, 0, 'fuel quantity burned per year')
